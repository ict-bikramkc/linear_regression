# %% [markdown]
# # Linear Regression

# %% [markdown]
# Simple Linear Regression For Salary Dataset inplemented in Jupyter Notebok

# %%
import numpy as np #variety of mathematical operations on arrays
import matplotlib.pyplot as plt #for creating static, animated, and interactive visualizations
import pandas as pd #used for working with data sets
import seaborn as sns #for drawing attractive and informative statistical graphics
# %matplotlib inline

# %% [markdown]
# Import science salary dataset and extract dependent and independent variables

# %%
salary_data = pd.read_csv('./Salary_Data.csv')
x=salary_data.iloc[:, :-1].values
y=salary_data.iloc[:, 1].values

# %% [markdown]
# Histogram Plot of Years Experience

# %%
sns.histplot(salary_data['YearsExperience'], kde=False, bins=10)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Count'>

# %% [markdown]
# Histogram Plot of Salary

# %%
sns.histplot(salary_data['Salary'], kde=False, bins=10)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %% [markdown]
# Count Plot of Years Experience

# %%
sns.countplot(y="YearsExperience", data=salary_data)
# Out:
# <Axes: xlabel='count', ylabel='YearsExperience'>

# %% [markdown]
# Count Plot of Salary

# %%
sns.countplot(y="Salary", data=salary_data)
# Out:
# <Axes: xlabel='count', ylabel='Salary'>

# %% [markdown]
# Bar Plot of Years Experience vs Salary

# %%
sns.barplot(x="YearsExperience", y="Salary", data=salary_data)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# HeatMap Plot of Salary Dataset

# %%
sns.heatmap(salary_data.corr())
# Out:
# <Axes: >
